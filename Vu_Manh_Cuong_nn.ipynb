# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
#
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
print("Number of GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Number of GPUs Available:  1

# %% [markdown]
# Data has been downloaded and stored in a folder 'images' divided into 'train' and 'test' folder.

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/content/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/content/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split=0.2,
  subset="training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split=0.2,
  subset="validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
#
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
plt.figure(figsize=(10,10))
for i in range(9):
  plt.subplot(3,3,i+1)
  image = plt.imread(
      str(list(data_dir_train.glob(f'{class_names[i]}/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)
  plt.axis('off')

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
#
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use `layers.experimental.preprocessing.Rescaling` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
model = Sequential()

# Rescaling layer for input normalization
model.add(layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)))

# First block of convolutions and pooling with dropout
model.add(Conv2D(32, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Second block of convolutions and pooling with dropout
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Third block of convolutions and pooling with dropout
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Fourth block of convolutions and pooling without dropout
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# Fifth block with increased kernel size and dropout
model.add(Conv2D(16, kernel_size=(7, 7), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Sixth block with even larger kernel size and dropout
model.add(Conv2D(128, kernel_size=(11, 11), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Seventh block of convolutions and pooling with dropout
model.add(Conv2D(256, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flatten the output of the convolutions
model.add(Flatten())

# Dense layers for classification
model.add(Dense(128, activation='relu'))
model.add(Dense(9, activation='softmax'))  # Assuming 9 classes for the output layer

# %% [markdown]
# ### Compile the model
#
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_7 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_7 (MaxPoolin  (None, 90, 90, 32)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_8 (MaxPoolin  (None, 45, 45, 64)        0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 45, 45, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 45, 45, 64)        36928
#
#  max_pooling2d_9 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 22, 22, 64)        36928
#
#  max_pooling2d_10 (MaxPooli  (None, 11, 11, 64)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 16)        50192
# ...

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
              callbacks=[learn_control]
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 839s 3s/step - loss: 2.0948 - accuracy: 0.1897 - val_loss: 2.0877 - val_accuracy: 0.1924 - lr: 0.0010
# Epoch 2/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0287 - accuracy: 0.1964 - val_loss: 2.0266 - val_accuracy: 0.1924 - lr: 0.0010
# Epoch 3/20
# 56/56 [==============================] - 4s 63ms/step - loss: 2.0164 - accuracy: 0.1992 - val_loss: 2.0202 - val_accuracy: 0.2103 - lr: 0.0010
# Epoch 4/20
# 56/56 [==============================] - 3s 62ms/step - loss: 1.9304 - accuracy: 0.2667 - val_loss: 1.7740 - val_accuracy: 0.3177 - lr: 0.0010
# Epoch 5/20
# 56/56 [==============================] - 3s 58ms/step - loss: 1.7768 - accuracy: 0.3331 - val_loss: 1.8734 - val_accuracy: 0.2685 - lr: 0.0010
# Epoch 6/20
# 56/56 [==============================] - 3s 57ms/step - loss: 1.7472 - accuracy: 0.3354 - val_loss: 1.6856 - val_accuracy: 0.3602 - lr: 0.0010
# Epoch 7/20
# ...

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# **Findings**
#
# 1. There is no clear evidence of severe overfitting, as the validation accuracy and loss are relatively in line with the training accuracy and loss. However, the fluctuations and slight increase in validation loss towards the end suggest the model may start to overfit if trained for more epochs.
# 2. The model does not show signs of underfitting as both the training and validation metrics improve over time, indicating that the model has capacity to learn and is doing so.
#
# ##=> CONCLUSION: The model is not good.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# augumentation strategy with flip,rotate,skew,shift, zoom, brightness, contrast, saturation, hue
data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.1)
  ]
)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
#
# ### Create the model, compile and train the model

# %%
from tensorflow.keras.layers.experimental import preprocessing


model = Sequential()

# Rescaling layer for input normalization
model.add(preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)))

# Add data augmentation layer
model.add(data_augmentation)

# First convolutional block with pooling and dropout
model.add(Conv2D(32, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Second convolutional block
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Third convolutional block
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Fourth convolutional block without dropout
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# Fifth convolutional block with increased kernel size and dropout
model.add(Conv2D(16, kernel_size=(7, 7), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Sixth convolutional block with a larger kernel size and dropout
model.add(Conv2D(128, kernel_size=(11, 11), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Seventh convolutional block
model.add(Conv2D(256, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flatten the output to feed into the dense layers
model.add(Flatten())

# Dense layer for deeper feature interpretation
model.add(Dense(128, activation='relu'))

# Output layer with softmax for multi-class classification
model.add(Dense(9, activation='softmax'))  # Assuming 9 classes for the output layer

# %% [markdown]
# ### Compiling the model

# %%
### Todo, choose an appropirate optimiser and loss function
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_2 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_14 (Conv2D)          (None, 180, 180, 32)      896
#
#  max_pooling2d_14 (MaxPooli  (None, 90, 90, 32)        0
#  ng2D)
#
#  dropout_12 (Dropout)        (None, 90, 90, 32)        0
#
#  conv2d_15 (Conv2D)          (None, 90, 90, 64)        18496
#
#  max_pooling2d_15 (MaxPooli  (None, 45, 45, 64)        0
#  ng2D)
#
#  dropout_13 (Dropout)        (None, 45, 45, 64)        0
#
#  conv2d_16 (Conv2D)          (None, 45, 45, 64)        36928
#
#  max_pooling2d_16 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  dropout_14 (Dropout)        (None, 22, 22, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 22, 22, 64)        36928
#
#  max_pooling2d_17 (MaxPooli  (None, 11, 11, 64)        0
#  ng2D)
#
# ...

# %% [markdown]
# ### Training the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
              callbacks=[learn_control]
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 65ms/step - loss: 2.0562 - accuracy: 0.2076 - val_loss: 2.0903 - val_accuracy: 0.1924 - lr: 0.0010
# Epoch 2/20
# 56/56 [==============================] - 4s 65ms/step - loss: 2.0339 - accuracy: 0.1903 - val_loss: 2.0234 - val_accuracy: 0.2058 - lr: 0.0010
# Epoch 3/20
# 56/56 [==============================] - 4s 65ms/step - loss: 2.0198 - accuracy: 0.1987 - val_loss: 2.0228 - val_accuracy: 0.2058 - lr: 0.0010
# Epoch 4/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0193 - accuracy: 0.1998 - val_loss: 2.0291 - val_accuracy: 0.2058 - lr: 0.0010
# Epoch 5/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0177 - accuracy: 0.2081 - val_loss: 2.0283 - val_accuracy: 0.1924 - lr: 0.0010
# Epoch 6/20
# 56/56 [==============================] - 4s 63ms/step - loss: 2.0205 - accuracy: 0.1992 - val_loss: 2.0319 - val_accuracy: 0.2058 - lr: 0.0010
# Epoch 7/20
# ...

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# **Findings**
#
# 1. Compared to the previous model run, the model does not show signs of overfitting. The closer alignment and less variability between the training and validation lines suggest that the model is generalizing better to new data.
# 2. There is no evidence of underfitting; the model's accuracy is improving, indicating that it is learning relevant patterns from the data.
# 3. The improvement in validation accuracy and the stabilization of validation loss indicate that modifications made to the model or training process have had a positive impact.
#
# ## CONCLUSION: there is a marked improvement in the model's performance in this run compared to the previous one, with less evidence of overfitting or underfitting, indicating effective changes have been made in the model training process.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
#
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
# images in each classes
class_diff=pd.DataFrame()
for i in range(len(class_names)):
  name= class_names[i]
  number = len(list(data_dir_train.glob(f'{class_names[i]}/*.jpg')))
  class_diff=class_diff.append({'class':name,'number':number},ignore_index=True)

class_diff
# Out:
# C:\Users\sukhi\AppData\Local\Temp\ipykernel_21188\3870358818.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   class_diff=class_diff.append({'class':name,'number':number},ignore_index=True)
# C:\Users\sukhi\AppData\Local\Temp\ipykernel_21188\3870358818.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   class_diff=class_diff.append({'class':name,'number':number},ignore_index=True)
# C:\Users\sukhi\AppData\Local\Temp\ipykernel_21188\3870358818.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   class_diff=class_diff.append({'class':name,'number':number},ignore_index=True)
# ...

# %%
class_diff.plot.bar(x='class',y='number',rot=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Findings**
#
# #### - Which class has the least number of samples?
#
# #### **Ans.** seborrheic keratosis (77)
#
# #### - Which classes dominate the data in terms proportionate number of samples?
#
# #### **Ans.** pigmented benign keratosis (462)

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
#
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# %conda install -c augmentor augmentor

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
class_names=['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
path_to_training_dataset="images/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to images/Train/actinic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x26BD1535130>: 100%|██████████| 500/500 [00:01<00:00, 437.93 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to images/Train/basal cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x26BD19A0340>: 100%|██████████| 500/500 [00:01<00:00, 420.90 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to images/Train/dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x26BD19AEB80>: 100%|██████████| 500/500 [00:01<00:00, 431.86 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to images/Train/melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x26A0BA7CFD0>: 100%|██████████| 500/500 [00:05<00:00, 88.40 Samples/s]
# Initialised with 357 image(s) found.
# ...

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob

path_list_new = list(glob(os.path.join(data_dir_train, '*','output', '*.jpg')))
path_list_new
# Out:
# ['images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_9c5f4a12-e97b-4ced-9733-adfd5461af84.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_def747d6-2842-44c6-a27e-3b824358fcf8.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_16885b8b-0993-4074-bfdf-f0c905d0a2c8.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_3bd4464a-5ca6-4af0-8edd-37b78d48c79c.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_55ecbbff-50eb-4885-9868-8c9770ad14d6.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_610f0be3-e172-4aea-9787-d14f9d3ec19b.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_6f9dfa78-6e74-4f1e-8b77-72f884987592.jpg',
# ...

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
# ...

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
for i in class_names:
    directory ='images/Train'
    directory_out ='images/Train'+'/'+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob(i+'/*.jpg')))
    length_out=len(list(class_directory_out.glob('*.jpg')))
    length_tot=length+length_out
    print(f'{i} has {length_tot} samples.')
# Out:
# actinic keratosis has 614 samples.
# basal cell carcinoma has 876 samples.
# dermatofibroma has 595 samples.
# melanoma has 938 samples.
# nevus has 857 samples.
# pigmented benign keratosis has 962 samples.
# seborrheic keratosis has 577 samples.
# squamous cell carcinoma has 681 samples.
# vascular lesion has 639 samples.

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="images/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
# Number of output classes (assuming 'class_names' is defined elsewhere in your code)
num_classes = len(class_names)

model = Sequential([
    # Input rescaling layer (assumes input images are 180x180x3)
    Rescaling(1./255, input_shape=(180, 180, 3)),

    # Convolutional layer block 1
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),

    # Convolutional layer block 2
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),

    # Convolutional layer block 3
    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),

    # Convolutional layer block 4 with larger kernel size
    Conv2D(256, kernel_size=(11, 11), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),

    # Dropout and flattening for transitioning to dense layers
    Dropout(0.5),
    Flatten(),

    # Dense layer block with dropout for regularization
    Dense(256, activation='relu'),
    Dropout(0.25),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(64, activation='relu'),
    Dropout(0.25),

    # Output layer with softmax activation for classification
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
### Todo, choose an appropirate optimiser and loss function
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_14 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_14 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_15 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_16 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 10, 10, 256)       3965184
#
#  max_pooling2d_17 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 5, 5, 256)         0
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 256)               1638656
#
# ...

# %% [markdown]
# #### **Todo:** Train your model

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
              callbacks=[learn_control]
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 13s 68ms/step - loss: 2.1472 - accuracy: 0.1712 - val_loss: 1.9704 - val_accuracy: 0.2843 - lr: 0.0010
# Epoch 2/50
# 169/169 [==============================] - 10s 58ms/step - loss: 1.8328 - accuracy: 0.2867 - val_loss: 1.6131 - val_accuracy: 0.4009 - lr: 0.0010
# Epoch 3/50
# 169/169 [==============================] - 10s 57ms/step - loss: 1.6417 - accuracy: 0.3711 - val_loss: 1.5030 - val_accuracy: 0.4068 - lr: 0.0010
# Epoch 4/50
# 169/169 [==============================] - 10s 57ms/step - loss: 1.5627 - accuracy: 0.3908 - val_loss: 1.4178 - val_accuracy: 0.4529 - lr: 0.0010
# Epoch 5/50
# 169/169 [==============================] - 10s 57ms/step - loss: 1.4866 - accuracy: 0.4275 - val_loss: 1.3411 - val_accuracy: 0.4581 - lr: 0.0010
# Epoch 6/50
# 169/169 [==============================] - 10s 57ms/step - loss: 1.4262 - accuracy: 0.4407 - val_loss: 1.3098 - val_accuracy: 0.4826 - lr: 0.0010
# Epoch 7/50
# ...

# %% [markdown]
# #### **Todo:** Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:** Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# **Findings**
# 1. There is no apparent sign of underfitting since the model reaches a high accuracy, meaning that it has sufficient capacity to learn from the dataset.
# 2. There is no clear evidence of overfitting. The small gap between the training and validation lines towards the end of the training process indicates that the model maintains its ability to generalize to unseen data.
# 3. The Validation accuracy is 87%

# %% [markdown]
# ### Test the model

# %%
from glob import glob
from tensorflow.keras.preprocessing.image import load_img, img_to_array
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print(f"Actual: {class_names[0]}" + '\n' + "Predictive: " + pred_class)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# Actual: actinic keratosis
# Predictive: pigmented benign keratosis
